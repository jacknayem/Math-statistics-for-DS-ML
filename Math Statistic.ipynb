# %% [markdown]
# <h1>Logarithm</h1>
# <h4>What is Logarithm?</h4>
# <p>Mathematics is a quantitatively solution of any problem. It represent two qualtative value, groth or decay. Every mathematical result show you groth or decay. A very basic example is might be your computer. Suppose your computer had 4GB RAM and you have connected another 8GB ram. The new addition of RAM indicate that you have increased your computer RAM capacity. Unfortunetly 4GB memory has been damage few week later. Now the computer RAM capacity has decrese.</p>
#
# <p>Another example is, some kind of bacteria make it double in a time.</p>
# <p><b>Like as 1 to 2, 2 to 4 and 4 to 8,....<br> = 1 2 4 8 16.....</b></p>
# <p>How many bacteria will be after 5 time iteration? What is the solution? Even if I ask you the total number of bacteria in bilinon time iteration. Exponentiation is the solution of this problem, which is fandamental arithmetic operations.</p>
# <p>$${b^{n} = b * b * b * ... * n_time_b}$$</p>
# <p>Here, b is the base value, where bacteria increase double mean b = 2. If bacteria increase triple, it will be b = 3. and n mean iteration, where n = 50th time iteration of bacteria. The equation will be:</p>
# <p>$${2^{5} = 2 * 2 * 2 * 2 * 2}$$</p>
# <p>As we can understand that exponentiation use to calculate the total number of object value after specific iteration. Let say you know the bacteria increase double and as you can see there 32 bacteria in a petri dish. how many iteration took to become 32 bacteria? Here we need to think reverse of exponentiation. which is logarithm. Let's have a look.</p>
# <p>The logarithm equation is:</p>
# <p>$$n = log_b{(t)}$$</p>
# <p>Here n is iteration, b is base value and t is our targeted value. From our question b = 2, t = 32</p>
# <p>$$n = log_2{(32)}$$</p>
# <h4>Why in Machine Learning?</h4>
# <p>In some case we need to visualize data to understand it. Somethime we struggle some kind of problem. For example </p>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import math
df = pd.DataFrame({'Company':['Uber', 'Pathao', 'Sheba xyz', 'Uthao', 'Obai'], 'Income in $M':[200, 8, 4.5, 7, 6]})
df.plot('Company', 'Income in $M', kind='bar')
plt.show()

# %% [markdown]
# <p>Look at the bar chart. Uber is more profitable company. But it is difficult to understand which is the second position and which is last. There is more solution to solve the problem. But logarithm is one the best way to solve. Let see a bar chart, How much effective it is.</p>

# %%
df['logIncome'] = [math.log(x) for x in df['Income in $M']]
df.plot('Company','logIncome', kind='bar')
plt.show()

# %% [markdown]
# <p>I think I do not need to explain what you can see in this chart.</p>
# <p>On the other hand, The fundamental goal of a ML model to find out the pattern of input and output. Using large range of value is pretty chanllenging to fit properly, which is cause of underfitting and overfitting. Transform data is the best way to overcome. Data transformation is the best ways when we encounter highly skewed data. Where we can use Logarithm to skewed data.</p>

# %%
df.plot.line(subplots=True)
plt.show()

# %% [markdown]
# Borh line graphs are for income. one is actual income and another is log Income. But The log income is more understandable. In same way a machine learning model can indentify the patter between input and output more easily.
